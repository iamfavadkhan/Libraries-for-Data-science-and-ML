# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

data = pd.DataFrame({
    'Day' : list(range(1 , 5)),
    'Temperature' : [32 ,33 ,43 ,31] 
})
sns.lineplot(x = 'Day' , y = 'Temperature' , data = data)
plt.grid()
plt.show()
