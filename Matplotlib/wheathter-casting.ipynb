# %% [markdown]
# Task: Analyze Weather Data Using Matplotlib
# 🎯 Objective:
# You will visualize the monthly weather data (temperature, rainfall, and humidity) of a fictional city using various Matplotlib plotting techniques.
#
# 📊 Given Data:
# python
# Copy
# Edit
# months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
#           'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# temperature = [7, 9, 14, 18, 23, 27, 30, 29, 25, 19, 13, 8]   # °C
# rainfall = [78, 60, 55, 48, 30, 20, 10, 12, 18, 35, 58, 72]  # mm
# humidity = [85, 80, 75, 70, 65, 60, 55, 58, 62, 70, 78, 82]  # %
# ✅ Your Tasks:
# Create a 2x2 subplot grid and plot the following:
#
# Plot 1: Line graph of temperature vs months
# Plot 2: Bar chart of rainfall vs months
# Plot 3: Line graph of humidity vs months (with markers)
# Plot 4: Combined line graph of all three metrics with labels and legend
# Add appropriate:
# Titles for each subplot
# X and Y axis labels
# Grid for better readability
# Custom colors and markers
# Rotate month labels for better visibility
# Use plt.tight_layout() to prevent overlapping
# 🧠 Bonus Challenge:
# Highlight the month with highest temperature using plt.annotate().
# Change the color of the bar representing highest rainfall in the bar chart.
#
# 💡 Hint Functions to Use:
# plt.subplot()
# plt.plot(), plt.bar()
# plt.title(), plt.xlabel(), plt.ylabel()
# plt.grid(), plt.legend(), plt.xticks(rotation=45)
# plt.annotate(), plt.tight_layout()

# %%
import matplotlib.pyplot as plt 

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
temperature = [7, 9, 14, 18, 23, 27, 30, 29, 25, 19, 13, 8]   # °C
rainfall = [78, 60, 55, 48, 30, 20, 10, 12, 18, 35, 58, 72]  # mm
humidity = [85, 80, 75, 70, 65, 60, 55, 58, 62, 70, 78, 82]  # %

#plot 1
plt.subplot(2,2,1)
plt.plot(temperature , months)
plt.xlabel("Months")
plt.ylabel("Temperature °C")

#plot 2
plt.subplot(2,2,2)
plt.bar(rainfall , months)
plt.xlabel("Rain Fall")
plt.ylabel("Months")

#plot 3
plt.subplot(2,2,3)
plt.plot(humidity , months)
plt.xlabel("Humadity")
plt.ylabel("Months")

#plot 4
plt.subplot(2, 2, 4)
plt.plot(temperature ,months , label="Temperature", marker='o')
plt.plot(rainfall, months ,label="Rainfall", marker='s')
plt.plot(humidity, months ,label="Humidity", marker='^')
plt.xlabel("Months")
plt.ylabel("Values")
plt.title("Weather Comparison")
plt.legend()
plt.tight_layout()
plt.show()
